# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import classification_report
from os import walk

# %% [markdown]
# # Preprocessing

# %%
def file_get_contents(filename): #Получаем контент файла
    with open(filename) as f:
        return f.read()

# %%
def getBacteriesData(content, bacteries): #Парсинг файла, сбор множества бактерий
	rows = content.split("\n")
	result = []
	skip = False
	for i in range(0, len(rows)):
		rows[i] = rows[i].split("\t")
		for j in range(0, len(rows[i])):
			rows[i][j] = rows[i][j].strip()
		if(len(rows[i]) < 4 or rows[i][3] not in ['D', 'P', 'C']):
			continue
		if(float(rows[i][0]) < 3.0):
			continue
		if skip and (rows[i][3] != 'D'):
			continue
		if(rows[i][3] == 'D'):
			if(rows[i][5] not in ['Bacteria', 'Archaea']):
				skip = True
			else:
				skip = False
		result.append({'name': rows[i][5], 'percentage': rows[i][0], 'count': rows[i][1]})
		bacteries.add(rows[i][5])
	return {'result' : result, 'bacteries' : bacteries}

# %%
def preproccess(info, key, bacteries): #Получение значений бактерий (key - либо count, либо percentage)
	result = []
	exist_bacteries = []
	for values in info:
		exist_bacteries.append(values['name'])

	for bactery in bacteries:
		if bactery not in exist_bacteries:
			result.append(0)
			continue
		for values in info:
			if values['name'] == bactery:
				result.append(float(values[key]))
				continue
				
	return result

# %%
def get_df(file_path, analyses_path, target=0):
	# Загружаем spreadsheet в объект pandas
	xl = pd.ExcelFile(file_path)

	#Преобразуем в DataFrame
	df = xl.parse('Sheet1')

	#Получаем масссив экспериментов
	s_runs = df["Run"].to_numpy()

	df.set_index('Run', inplace=True)

	df['target'] = pd.Series([target] * len(df['Age']), index=df.index)

	runs = next(walk(analyses_path), (None, None, []))[2]  # [] if no file

	bacteries = set() #Список бактерий

	runs_dict = []
	runs_id = []

	for run in s_runs:
		if run in runs:
			result = getBacteriesData(file_get_contents(analyses_path + run), bacteries)
			bacteries = result['bacteries']
			runs_dict.append(result['result'])
			runs_id.append(run)

	bacteries = list(bacteries)
	bacteries.sort()

	#for percentage
	df_bacteries = []

	for run_item in runs_dict:
		df_bacteries.append(preproccess(run_item, 'percentage', bacteries))

	df_cols = []

	for bactery in bacteries:
		df_cols.append(bactery + '_percentage')

	df_bacteries = pd.DataFrame(df_bacteries, columns = df_cols, index=runs_id)
	cols = df_bacteries.columns

	for column in cols:
		df[column] = df_bacteries[column]

	if 'Unnamed: 0' in df.columns:
		df.drop('Unnamed: 0', axis=1, inplace=True)

	return df

# %% [markdown]
# # Obesity

# %%
file_path = 'obesity.xlsx'
analyses_path = 'C:\\Users\\admin1\\Documents\\Микробиом\\obesity\\' #Путь до исследований
df_obesity = get_df(file_path, analyses_path, 0)

# %%
file_path = 'health.xlsx'
analyses_path = 'C:\\Users\\admin1\\Documents\\Микробиом\\health\\' #Путь до исследований
df_health = get_df(file_path, analyses_path, 1)

# %%
df_common = df_health.append(df_obesity).fillna(0)
# Out:
# C:\Users\admin1\AppData\Local\Temp\ipykernel_1448\131401743.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_common = df_health.append(df_obesity).fillna(0)

# %% [markdown]
# ## Tree classifier

# %%
feature_cols = list(df_common.columns)
feature_cols = [col for col in feature_cols if col != 'BioSample' and col != 'target' and col != 'Region']
X = df_common[feature_cols] # Features
y = df_common.target # Target variable
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       125
#            1       1.00      1.00      1.00        73
#
#     accuracy                           1.00       198
#    macro avg       1.00      1.00      1.00       198
# weighted avg       1.00      1.00      1.00       198

# %% [markdown]
# ## Data Groups

# %%
print('Возраст от 18 до 30, BMI от 25 до 29.9')

df_obesity_18_30 = df_obesity.query("Age >= 18 and Age <= 30 and BMI >= 25 and BMI <= 29.9")
print(df_obesity_18_30.describe())
# Out:
# Возраст от 18 до 30, BMI от 25 до 29.9
#              Age        BMI  target  Actinobacteria_percentage  \
# count  53.000000  53.000000    53.0                  53.000000
# mean   26.056604  26.913208     0.0                   6.342453
# std     3.078555   1.258515     0.0                   9.492084
# min    18.000000  25.000000     0.0                   0.000000
# 25%    24.000000  26.000000     0.0                   0.000000
# 50%    27.000000  26.400000     0.0                   0.000000
# 75%    29.000000  27.400000     0.0                   9.050000
# max    30.000000  29.800000     0.0                  35.630000
#
#        Actinobacteriota_percentage  Alphaproteobacteria_percentage  \
# count                    53.000000                            53.0
# mean                      8.633962                             0.0
# std                      10.428504                             0.0
# min                       0.000000                             0.0
# 25%                       0.000000                             0.0
# 50%                       5.250000                             0.0
# 75%                      12.860000                             0.0
# max                      37.430000                             0.0
#
#        Archaea_percentage  Bacilli_percentage  Bacteria_percentage  \
# count           53.000000           53.000000            53.000000
# mean             1.205283            5.171321            98.193585
# std              3.829707            5.967599             3.747482
# min              0.000000            0.000000            76.490000
# 25%              0.000000            0.000000            98.260000
# 50%              0.000000            3.930000            99.470000
# 75%              0.000000            8.550000            99.690000
# max             23.360000           26.360000            99.860000
#
#        Bacteroidia_percentage  ...  Methanobacteria_percentage  \
# count               53.000000  ...                    53.00000
# mean                16.576981  ...                     1.20434
# std                 14.641714  ...                     3.82735
# min                  0.000000  ...                     0.00000
# 25%                  4.450000  ...                     0.00000
# 50%                 13.480000  ...                     0.00000
# 75%                 25.190000  ...                     0.00000
# max                 57.210000  ...                    23.35000
#
#        Negativicutes_percentage  Proteobacteria_percentage  \
# count                 53.000000                  53.000000
# mean                   2.634340                   5.281321
# std                    5.023125                  11.484655
# min                    0.000000                   0.000000
# 25%                    0.000000                   0.000000
# 50%                    0.000000                   0.000000
# 75%                    4.210000                   6.100000
# max                   27.980000                  53.260000
#
#        Spirochaetia_percentage  Spirochaetota_percentage  \
# count                     53.0                      53.0
# mean                       0.0                       0.0
# std                        0.0                       0.0
# min                        0.0                       0.0
# 25%                        0.0                       0.0
# 50%                        0.0                       0.0
# 75%                        0.0                       0.0
# max                        0.0                       0.0
#
#        Synergistia_percentage  Synergistota_percentage  \
# count                    53.0                     53.0
# mean                      0.0                      0.0
# std                       0.0                      0.0
# min                       0.0                      0.0
# 25%                       0.0                      0.0
# 50%                       0.0                      0.0
# 75%                       0.0                      0.0
# max                       0.0                      0.0
#
#        Vampirivibrionia_percentage  Verrucomicrobiae_percentage  \
# count                         53.0                    53.000000
# mean                           0.0                     4.348679
# std                            0.0                    12.982402
# min                            0.0                     0.000000
# 25%                            0.0                     0.000000
# 50%                            0.0                     0.000000
# 75%                            0.0                     0.000000
# max                            0.0                    76.880000
#
#        Verrucomicrobiota_percentage
# count                     53.000000
# mean                       4.353774
# std                       12.991033
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.000000
# max                       76.900000
#
# [8 rows x 31 columns]

# %%
print('Возраст от 18 до 30, BMI от 30 до 39.9')

df_obesity_18_30 = df_obesity.query("Age >= 18 and Age <= 30 and BMI >= 30 and BMI <= 39.9")
print(df_obesity_18_30.describe())
# Out:
# Возраст от 18 до 30, BMI от 30 до 39.9
#              Age        BMI  target  Actinobacteria_percentage  \
# count  13.000000  13.000000    13.0                   13.00000
# mean   28.230769  33.103077     0.0                    1.18000
# std     1.363442   2.349796     0.0                    3.22993
# min    25.000000  30.690000     0.0                    0.00000
# 25%    28.000000  31.500000     0.0                    0.00000
# 50%    28.000000  32.400000     0.0                    0.00000
# 75%    29.000000  33.550000     0.0                    0.00000
# max    30.000000  38.960000     0.0                   11.25000
#
#        Actinobacteriota_percentage  Alphaproteobacteria_percentage  \
# count                    13.000000                            13.0
# mean                      3.089231                             0.0
# std                       7.132495                             0.0
# min                       0.000000                             0.0
# 25%                       0.000000                             0.0
# 50%                       0.000000                             0.0
# 75%                       0.000000                             0.0
# max                      23.170000                             0.0
#
#        Archaea_percentage  Bacilli_percentage  Bacteria_percentage  \
# count           13.000000           13.000000            13.000000
# mean             0.256923            6.609231            98.640000
# std              0.926349            6.477913             0.879612
# min              0.000000            0.000000            96.330000
# 25%              0.000000            0.000000            98.570000
# 50%              0.000000            4.580000            98.690000
# 75%              0.000000           10.740000            99.060000
# max              3.340000           21.080000            99.800000
#
#        Bacteroidia_percentage  ...  Methanobacteria_percentage  \
# count               13.000000  ...                   13.000000
# mean                11.399231  ...                    0.256923
# std                 10.367152  ...                    0.926349
# min                  0.000000  ...                    0.000000
# 25%                  3.470000  ...                    0.000000
# 50%                  8.830000  ...                    0.000000
# 75%                 15.740000  ...                    0.000000
# max                 37.490000  ...                    3.340000
#
#        Negativicutes_percentage  Proteobacteria_percentage  \
# count                 13.000000                  13.000000
# mean                   3.762308                   6.340000
# std                    7.587042                   7.868793
# min                    0.000000                   0.000000
# 25%                    0.000000                   0.000000
# 50%                    0.000000                   4.160000
# 75%                    0.000000                   8.820000
# max                   22.520000                  20.040000
#
#        Spirochaetia_percentage  Spirochaetota_percentage  \
# count                     13.0                      13.0
# mean                       0.0                       0.0
# std                        0.0                       0.0
# min                        0.0                       0.0
# 25%                        0.0                       0.0
# 50%                        0.0                       0.0
# 75%                        0.0                       0.0
# max                        0.0                       0.0
#
#        Synergistia_percentage  Synergistota_percentage  \
# count                    13.0                     13.0
# mean                      0.0                      0.0
# std                       0.0                      0.0
# min                       0.0                      0.0
# 25%                       0.0                      0.0
# 50%                       0.0                      0.0
# 75%                       0.0                      0.0
# max                       0.0                      0.0
#
#        Vampirivibrionia_percentage  Verrucomicrobiae_percentage  \
# count                    13.000000                    13.000000
# mean                      0.410769                     0.474615
# std                       1.481050                     1.711250
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.000000                     0.000000
# max                       5.340000                     6.170000
#
#        Verrucomicrobiota_percentage
# count                     13.000000
# mean                       0.474615
# std                        1.711250
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.000000
# max                        6.170000
#
# [8 rows x 31 columns]

# %%
print('Возраст от 18 до 30, BMI от 40')

df_obesity_18_30 = df_obesity.query("Age >= 18 and Age <= 30 and BMI >= 40")
print(df_obesity_18_30.describe())
# Out:
# Возраст от 18 до 30, BMI от 40
#              Age        BMI  target  Actinobacteria_percentage  \
# count   4.000000   4.000000     4.0                        4.0
# mean   27.500000  47.887500     0.0                        0.0
# std     2.081666   5.348653     0.0                        0.0
# min    25.000000  41.370000     0.0                        0.0
# 25%    26.500000  45.817500     0.0                        0.0
# 50%    27.500000  47.880000     0.0                        0.0
# 75%    28.500000  49.950000     0.0                        0.0
# max    30.000000  54.420000     0.0                        0.0
#
#        Actinobacteriota_percentage  Alphaproteobacteria_percentage  \
# count                          4.0                             4.0
# mean                           0.0                             0.0
# std                            0.0                             0.0
# min                            0.0                             0.0
# 25%                            0.0                             0.0
# 50%                            0.0                             0.0
# 75%                            0.0                             0.0
# max                            0.0                             0.0
#
#        Archaea_percentage  Bacilli_percentage  Bacteria_percentage  \
# count                 4.0                 4.0             4.000000
# mean                  0.0                 0.0            98.905000
# std                   0.0                 0.0             0.164418
# min                   0.0                 0.0            98.670000
# 25%                   0.0                 0.0            98.865000
# 50%                   0.0                 0.0            98.950000
# 75%                   0.0                 0.0            98.990000
# max                   0.0                 0.0            99.050000
#
#        Bacteroidia_percentage  ...  Methanobacteria_percentage  \
# count                4.000000  ...                         4.0
# mean                22.270000  ...                         0.0
# std                 20.416162  ...                         0.0
# min                  3.110000  ...                         0.0
# 25%                  5.645000  ...                         0.0
# 50%                 21.385000  ...                         0.0
# 75%                 38.010000  ...                         0.0
# max                 43.200000  ...                         0.0
#
#        Negativicutes_percentage  Proteobacteria_percentage  \
# count                  4.000000                        4.0
# mean                   6.395000                        0.0
# std                   10.388922                        0.0
# min                    0.000000                        0.0
# 25%                    0.000000                        0.0
# 50%                    1.920000                        0.0
# 75%                    8.315000                        0.0
# max                   21.740000                        0.0
#
#        Spirochaetia_percentage  Spirochaetota_percentage  \
# count                      4.0                       4.0
# mean                       0.0                       0.0
# std                        0.0                       0.0
# min                        0.0                       0.0
# 25%                        0.0                       0.0
# 50%                        0.0                       0.0
# 75%                        0.0                       0.0
# max                        0.0                       0.0
#
#        Synergistia_percentage  Synergistota_percentage  \
# count                     4.0                      4.0
# mean                      0.0                      0.0
# std                       0.0                      0.0
# min                       0.0                      0.0
# 25%                       0.0                      0.0
# 50%                       0.0                      0.0
# 75%                       0.0                      0.0
# max                       0.0                      0.0
#
#        Vampirivibrionia_percentage  Verrucomicrobiae_percentage  \
# count                          4.0                          4.0
# mean                           0.0                          0.0
# std                            0.0                          0.0
# min                            0.0                          0.0
# 25%                            0.0                          0.0
# 50%                            0.0                          0.0
# 75%                            0.0                          0.0
# max                            0.0                          0.0
#
#        Verrucomicrobiota_percentage
# count                           4.0
# mean                            0.0
# std                             0.0
# min                             0.0
# 25%                             0.0
# 50%                             0.0
# 75%                             0.0
# max                             0.0
#
# [8 rows x 31 columns]

# %%
print('Возраст от 31 до 45, BMI от 25 до 29.9')

df_obesity_18_30 = df_obesity.query("Age >= 31 and Age <= 45 and BMI >= 25 and BMI <= 29.9")
print(df_obesity_18_30.describe())
# Out:
# Возраст от 31 до 45, BMI от 25 до 29.9
#               Age         BMI  target  Actinobacteria_percentage  \
# count  127.000000  127.000000   127.0                 127.000000
# mean    38.267717   26.740630     0.0                   6.024882
# std      4.667430    1.285127     0.0                   7.892459
# min     31.000000   25.000000     0.0                   0.000000
# 25%     34.000000   26.000000     0.0                   0.000000
# 50%     38.000000   26.000000     0.0                   3.340000
# 75%     43.000000   27.650000     0.0                   9.800000
# max     45.000000   29.900000     0.0                  33.280000
#
#        Actinobacteriota_percentage  Alphaproteobacteria_percentage  \
# count                   127.000000                      127.000000
# mean                      8.704173                        0.031181
# std                       9.794606                        0.351393
# min                       0.000000                        0.000000
# 25%                       0.000000                        0.000000
# 50%                       5.700000                        0.000000
# 75%                      12.620000                        0.000000
# max                      54.850000                        3.960000
#
#        Archaea_percentage  Bacilli_percentage  Bacteria_percentage  \
# count          127.000000          127.000000           127.000000
# mean             0.888740            5.003386            98.571024
# std              2.916497            5.916035             2.861834
# min              0.000000            0.000000            79.320000
# 25%              0.000000            0.000000            99.255000
# 50%              0.000000            4.040000            99.480000
# 75%              0.000000            6.960000            99.640000
# max             20.470000           36.150000            99.870000
#
#        Bacteroidia_percentage  ...  Methanobacteria_percentage  \
# count              127.000000  ...                  127.000000
# mean                15.450787  ...                    0.888189
# std                 14.106181  ...                    2.914477
# min                  0.000000  ...                    0.000000
# 25%                  4.560000  ...                    0.000000
# 50%                 11.250000  ...                    0.000000
# 75%                 24.360000  ...                    0.000000
# max                 60.770000  ...                   20.460000
#
#        Negativicutes_percentage  Proteobacteria_percentage  \
# count                127.000000                 127.000000
# mean                   3.319921                   2.939055
# std                    7.681740                   8.168012
# min                    0.000000                   0.000000
# 25%                    0.000000                   0.000000
# 50%                    0.000000                   0.000000
# 75%                    3.475000                   0.000000
# max                   54.400000                  51.650000
#
#        Spirochaetia_percentage  Spirochaetota_percentage  \
# count                    127.0                     127.0
# mean                       0.0                       0.0
# std                        0.0                       0.0
# min                        0.0                       0.0
# 25%                        0.0                       0.0
# 50%                        0.0                       0.0
# 75%                        0.0                       0.0
# max                        0.0                       0.0
#
#        Synergistia_percentage  Synergistota_percentage  \
# count              127.000000               127.000000
# mean                 0.062126                 0.062126
# std                  0.700124                 0.700124
# min                  0.000000                 0.000000
# 25%                  0.000000                 0.000000
# 50%                  0.000000                 0.000000
# 75%                  0.000000                 0.000000
# max                  7.890000                 7.890000
#
#        Vampirivibrionia_percentage  Verrucomicrobiae_percentage  \
# count                   127.000000                   127.000000
# mean                      0.129055                     1.643780
# std                       1.192399                     5.573502
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.000000                     0.000000
# max                      13.040000                    32.200000
#
#        Verrucomicrobiota_percentage
# count                    127.000000
# mean                       1.647717
# std                        5.585638
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.000000
# max                       32.290000
#
# [8 rows x 31 columns]

# %%
print('Возраст от 31 до 45, BMI от 30 до 39.9')

df_obesity_18_30 = df_obesity.query("Age >= 31 and Age <= 45 and BMI >= 30 and BMI <= 39.9")
print(df_obesity_18_30.describe())
# Out:
# Возраст от 31 до 45, BMI от 30 до 39.9
#              Age        BMI  target  Actinobacteria_percentage  \
# count  70.000000  70.000000    70.0                  70.000000
# mean   38.428571  33.493429     0.0                   2.001286
# std     4.732164   2.745087     0.0                   6.191326
# min    31.000000  30.000000     0.0                   0.000000
# 25%    34.000000  31.147500     0.0                   0.000000
# 50%    39.000000  32.980000     0.0                   0.000000
# 75%    43.000000  35.392500     0.0                   0.000000
# max    45.000000  39.900000     0.0                  44.530000
#
#        Actinobacteriota_percentage  Alphaproteobacteria_percentage  \
# count                    70.000000                            70.0
# mean                      4.397143                             0.0
# std                       8.486619                             0.0
# min                       0.000000                             0.0
# 25%                       0.000000                             0.0
# 50%                       0.000000                             0.0
# 75%                       6.542500                             0.0
# max                      53.740000                             0.0
#
#        Archaea_percentage  Bacilli_percentage  Bacteria_percentage  \
# count           70.000000           70.000000            70.000000
# mean             1.581714            3.945286            97.551286
# std              4.568787            4.634429             4.410504
# min              0.000000            0.000000            74.010000
# 25%              0.000000            0.000000            98.390000
# 50%              0.000000            1.585000            98.830000
# 75%              0.000000            7.852500            99.462500
# max             25.820000           16.550000            99.820000
#
#        Bacteroidia_percentage  ...  Methanobacteria_percentage  \
# count               70.000000  ...                   70.000000
# mean                13.721571  ...                    1.580429
# std                 12.374965  ...                    4.565785
# min                  0.000000  ...                    0.000000
# 25%                  4.170000  ...                    0.000000
# 50%                 10.110000  ...                    0.000000
# 75%                 19.375000  ...                    0.000000
# max                 48.660000  ...                   25.810000
#
#        Negativicutes_percentage  Proteobacteria_percentage  \
# count                 70.000000                  70.000000
# mean                   3.809000                   4.510714
# std                    8.432282                   8.637748
# min                    0.000000                   0.000000
# 25%                    0.000000                   0.000000
# 50%                    0.000000                   0.000000
# 75%                    4.890000                   5.570000
# max                   50.880000                  44.220000
#
#        Spirochaetia_percentage  Spirochaetota_percentage  \
# count                70.000000                 70.000000
# mean                  0.174857                  0.174857
# std                   1.028773                  1.028773
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   0.000000                  0.000000
# 75%                   0.000000                  0.000000
# max                   6.480000                  6.480000
#
#        Synergistia_percentage  Synergistota_percentage  \
# count                    70.0                     70.0
# mean                      0.0                      0.0
# std                       0.0                      0.0
# min                       0.0                      0.0
# 25%                       0.0                      0.0
# 50%                       0.0                      0.0
# 75%                       0.0                      0.0
# max                       0.0                      0.0
#
#        Vampirivibrionia_percentage  Verrucomicrobiae_percentage  \
# count                    70.000000                    70.000000
# mean                      0.133429                     2.182857
# std                       1.116344                     6.419884
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.000000                     0.000000
# max                       9.340000                    27.950000
#
#        Verrucomicrobiota_percentage
# count                     70.000000
# mean                       2.188143
# std                        6.432314
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.000000
# max                       27.970000
#
# [8 rows x 31 columns]

# %%
print('Возраст от 31 до 45, BMI от 40')

df_obesity_18_30 = df_obesity.query("Age >= 31 and Age <= 45 and BMI >= 40")
print(df_obesity_18_30.describe())
# Out:
# Возраст от 31 до 45, BMI от 40
#              Age        BMI  target  Actinobacteria_percentage  \
# count  30.000000  30.000000    30.0                  30.000000
# mean   36.500000  46.155000     0.0                   0.608667
# std     4.216143   5.405695     0.0                   1.934703
# min    31.000000  40.150000     0.0                   0.000000
# 25%    32.000000  42.112500     0.0                   0.000000
# 50%    35.000000  45.050000     0.0                   0.000000
# 75%    40.000000  48.662500     0.0                   0.000000
# max    44.000000  64.500000     0.0                   8.030000
#
#        Actinobacteriota_percentage  Alphaproteobacteria_percentage  \
# count                    30.000000                            30.0
# mean                      0.680667                             0.0
# std                       2.175470                             0.0
# min                       0.000000                             0.0
# 25%                       0.000000                             0.0
# 50%                       0.000000                             0.0
# 75%                       0.000000                             0.0
# max                       8.770000                             0.0
#
#        Archaea_percentage  Bacilli_percentage  Bacteria_percentage  \
# count                30.0            30.00000            30.000000
# mean                  0.0             2.71100            98.847333
# std                   0.0             6.12629             0.431421
# min                   0.0             0.00000            98.200000
# 25%                   0.0             0.00000            98.530000
# 50%                   0.0             0.00000            98.865000
# 75%                   0.0             2.52000            99.032500
# max                   0.0            28.09000            99.760000
#
#        Bacteroidia_percentage  ...  Methanobacteria_percentage  \
# count               30.000000  ...                        30.0
# mean                18.112667  ...                         0.0
# std                 11.384234  ...                         0.0
# min                  0.000000  ...                         0.0
# 25%                  9.292500  ...                         0.0
# 50%                 16.185000  ...                         0.0
# 75%                 21.835000  ...                         0.0
# max                 46.070000  ...                         0.0
#
#        Negativicutes_percentage  Proteobacteria_percentage  \
# count                 30.000000                  30.000000
# mean                   8.611333                   0.981667
# std                   11.788581                   2.117702
# min                    0.000000                   0.000000
# 25%                    0.000000                   0.000000
# 50%                    4.250000                   0.000000
# 75%                    9.025000                   0.000000
# max                   45.360000                   7.380000
#
#        Spirochaetia_percentage  Spirochaetota_percentage  \
# count                30.000000                 30.000000
# mean                  0.579333                  0.579333
# std                   3.173139                  3.173139
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   0.000000                  0.000000
# 75%                   0.000000                  0.000000
# max                  17.380000                 17.380000
#
#        Synergistia_percentage  Synergistota_percentage  \
# count                    30.0                     30.0
# mean                      0.0                      0.0
# std                       0.0                      0.0
# min                       0.0                      0.0
# 25%                       0.0                      0.0
# 50%                       0.0                      0.0
# 75%                       0.0                      0.0
# max                       0.0                      0.0
#
#        Vampirivibrionia_percentage  Verrucomicrobiae_percentage  \
# count                     30.00000                    30.000000
# mean                       0.12600                     0.361667
# std                        0.69013                     1.382247
# min                        0.00000                     0.000000
# 25%                        0.00000                     0.000000
# 50%                        0.00000                     0.000000
# 75%                        0.00000                     0.000000
# max                        3.78000                     5.910000
#
#        Verrucomicrobiota_percentage
# count                     30.000000
# mean                       0.365333
# std                        1.396263
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.000000
# max                        5.970000
#
# [8 rows x 31 columns]

# %%
print('Возраст от 46 до 65, BMI от 25 до 29.9')

df_obesity_18_30 = df_obesity.query("Age >= 46 and Age <= 65 and BMI >= 25 and BMI <= 29.9")
print(df_obesity_18_30.describe())
# Out:
# Возраст от 46 до 65, BMI от 25 до 29.9
#              Age        BMI  target  Actinobacteria_percentage  \
# count  46.000000  46.000000    46.0                   46.00000
# mean   52.630435  26.811522     0.0                    3.52913
# std     4.458992   1.224843     0.0                    5.38833
# min    46.000000  25.100000     0.0                    0.00000
# 25%    49.000000  26.000000     0.0                    0.00000
# 50%    53.500000  26.300000     0.0                    0.00000
# 75%    56.000000  27.675000     0.0                    6.31250
# max    62.000000  29.700000     0.0                   21.07000
#
#        Actinobacteriota_percentage  Alphaproteobacteria_percentage  \
# count                    46.000000                       46.000000
# mean                      6.224348                        0.143478
# std                       6.728965                        0.683150
# min                       0.000000                        0.000000
# 25%                       0.000000                        0.000000
# 50%                       4.115000                        0.000000
# 75%                      10.795000                        0.000000
# max                      23.240000                        3.590000
#
#        Archaea_percentage  Bacilli_percentage  Bacteria_percentage  \
# count           46.000000           46.000000            46.000000
# mean             1.091087            4.867174            98.388913
# std              4.806631            6.635056             4.761373
# min              0.000000            0.000000            68.850000
# 25%              0.000000            0.000000            99.332500
# 50%              0.000000            0.000000            99.590000
# 75%              0.000000            8.730000            99.727500
# max             31.010000           24.730000            99.840000
#
#        Bacteroidia_percentage  ...  Methanobacteria_percentage  \
# count               46.000000  ...                   46.000000
# mean                18.088478  ...                    1.090652
# std                 16.835533  ...                    4.804893
# min                  0.000000  ...                    0.000000
# 25%                  4.675000  ...                    0.000000
# 50%                 12.900000  ...                    0.000000
# 75%                 29.300000  ...                    0.000000
# max                 60.480000  ...                   31.000000
#
#        Negativicutes_percentage  Proteobacteria_percentage  \
# count                 46.000000                  46.000000
# mean                   2.456957                   4.787826
# std                    6.636794                   8.307941
# min                    0.000000                   0.000000
# 25%                    0.000000                   0.000000
# 50%                    0.000000                   0.000000
# 75%                    0.000000                   4.925000
# max                   30.260000                  33.510000
#
#        Spirochaetia_percentage  Spirochaetota_percentage  \
# count                     46.0                      46.0
# mean                       0.0                       0.0
# std                        0.0                       0.0
# min                        0.0                       0.0
# 25%                        0.0                       0.0
# 50%                        0.0                       0.0
# 75%                        0.0                       0.0
# max                        0.0                       0.0
#
#        Synergistia_percentage  Synergistota_percentage  \
# count                    46.0                     46.0
# mean                      0.0                      0.0
# std                       0.0                      0.0
# min                       0.0                      0.0
# 25%                       0.0                      0.0
# 50%                       0.0                      0.0
# 75%                       0.0                      0.0
# max                       0.0                      0.0
#
#        Vampirivibrionia_percentage  Verrucomicrobiae_percentage  \
# count                    46.000000                    46.000000
# mean                      0.076957                     3.267826
# std                       0.521945                     9.502219
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.000000                     0.000000
# max                       3.540000                    46.060000
#
#        Verrucomicrobiota_percentage
# count                     46.000000
# mean                       3.272826
# std                        9.513620
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.000000
# max                       46.100000
#
# [8 rows x 31 columns]

# %%
print('Возраст от 46 до 65, BMI от 30 до 39.9')

df_obesity_18_30 = df_obesity.query("Age >= 46 and Age <= 65 and BMI >= 30 and BMI <= 39.9")
print(df_obesity_18_30.describe())
# Out:
# Возраст от 46 до 65, BMI от 30 до 39.9
#              Age        BMI  target  Actinobacteria_percentage  \
# count  44.000000  44.000000    44.0                  44.000000
# mean   53.136364  33.061364     0.0                   1.838636
# std     4.618421   2.109691     0.0                   3.809872
# min    46.000000  30.200000     0.0                   0.000000
# 25%    49.750000  31.475000     0.0                   0.000000
# 50%    53.000000  32.900000     0.0                   0.000000
# 75%    56.000000  33.975000     0.0                   3.147500
# max    64.000000  38.200000     0.0                  16.900000
#
#        Actinobacteriota_percentage  Alphaproteobacteria_percentage  \
# count                    44.000000                            44.0
# mean                      6.029773                             0.0
# std                       8.349475                             0.0
# min                       0.000000                             0.0
# 25%                       0.000000                             0.0
# 50%                       1.805000                             0.0
# 75%                       9.295000                             0.0
# max                      32.600000                             0.0
#
#        Archaea_percentage  Bacilli_percentage  Bacteria_percentage  \
# count           44.000000           44.000000            44.000000
# mean             0.532727            6.852727            99.098182
# std              3.533713            8.740100             3.514525
# min              0.000000            0.000000            76.390000
# 25%              0.000000            0.000000            99.532500
# 50%              0.000000            4.090000            99.745000
# 75%              0.000000            8.997500            99.772500
# max             23.440000           32.910000            99.820000
#
#        Bacteroidia_percentage  ...  Methanobacteria_percentage  \
# count               44.000000  ...                   44.000000
# mean                16.676136  ...                    0.532273
# std                 15.662807  ...                    3.530698
# min                  0.000000  ...                    0.000000
# 25%                  3.997500  ...                    0.000000
# 50%                 11.640000  ...                    0.000000
# 75%                 25.960000  ...                    0.000000
# max                 54.070000  ...                   23.420000
#
#        Negativicutes_percentage  Proteobacteria_percentage  \
# count                 44.000000                  44.000000
# mean                   4.049318                   4.245909
# std                    6.671811                   7.267317
# min                    0.000000                   0.000000
# 25%                    0.000000                   0.000000
# 50%                    0.000000                   0.000000
# 75%                    6.960000                   6.160000
# max                   32.590000                  28.750000
#
#        Spirochaetia_percentage  Spirochaetota_percentage  \
# count                     44.0                      44.0
# mean                       0.0                       0.0
# std                        0.0                       0.0
# min                        0.0                       0.0
# 25%                        0.0                       0.0
# 50%                        0.0                       0.0
# 75%                        0.0                       0.0
# max                        0.0                       0.0
#
#        Synergistia_percentage  Synergistota_percentage  \
# count                    44.0                     44.0
# mean                      0.0                      0.0
# std                       0.0                      0.0
# min                       0.0                      0.0
# 25%                       0.0                      0.0
# 50%                       0.0                      0.0
# 75%                       0.0                      0.0
# max                       0.0                      0.0
#
#        Vampirivibrionia_percentage  Verrucomicrobiae_percentage  \
# count                    44.000000                    44.000000
# mean                      0.681591                     3.230909
# std                       3.126860                     9.063162
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.000000                     0.000000
# max                      19.580000                    45.240000
#
#        Verrucomicrobiota_percentage
# count                     44.000000
# mean                       3.239773
# std                        9.084649
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.000000
# max                       45.340000
#
# [8 rows x 31 columns]

# %%
print('Возраст от 46 до 65, BMI от 40')

df_obesity_18_30 = df_obesity.query("Age >= 46 and Age <= 65 and BMI >= 40")
print(df_obesity_18_30.describe())
# Out:
# Возраст от 46 до 65, BMI от 40
#         Age   BMI  target  Actinobacteria_percentage  \
# count   1.0   1.0     1.0                        1.0
# mean   50.0  47.2     0.0                        0.0
# std     NaN   NaN     NaN                        NaN
# min    50.0  47.2     0.0                        0.0
# 25%    50.0  47.2     0.0                        0.0
# 50%    50.0  47.2     0.0                        0.0
# 75%    50.0  47.2     0.0                        0.0
# max    50.0  47.2     0.0                        0.0
#
#        Actinobacteriota_percentage  Alphaproteobacteria_percentage  \
# count                          1.0                             1.0
# mean                           0.0                             0.0
# std                            NaN                             NaN
# min                            0.0                             0.0
# 25%                            0.0                             0.0
# 50%                            0.0                             0.0
# 75%                            0.0                             0.0
# max                            0.0                             0.0
#
#        Archaea_percentage  Bacilli_percentage  Bacteria_percentage  \
# count                 1.0                 1.0                 1.00
# mean                  0.0                 0.0                99.78
# std                   NaN                 NaN                  NaN
# min                   0.0                 0.0                99.78
# 25%                   0.0                 0.0                99.78
# 50%                   0.0                 0.0                99.78
# 75%                   0.0                 0.0                99.78
# max                   0.0                 0.0                99.78
#
#        Bacteroidia_percentage  ...  Methanobacteria_percentage  \
# count                    1.00  ...                         1.0
# mean                    34.91  ...                         0.0
# std                       NaN  ...                         NaN
# min                     34.91  ...                         0.0
# 25%                     34.91  ...                         0.0
# 50%                     34.91  ...                         0.0
# 75%                     34.91  ...                         0.0
# max                     34.91  ...                         0.0
#
#        Negativicutes_percentage  Proteobacteria_percentage  \
# count                      1.00                       1.00
# mean                      11.69                       8.39
# std                         NaN                        NaN
# min                       11.69                       8.39
# 25%                       11.69                       8.39
# 50%                       11.69                       8.39
# 75%                       11.69                       8.39
# max                       11.69                       8.39
#
#        Spirochaetia_percentage  Spirochaetota_percentage  \
# count                      1.0                       1.0
# mean                       0.0                       0.0
# std                        NaN                       NaN
# min                        0.0                       0.0
# 25%                        0.0                       0.0
# 50%                        0.0                       0.0
# 75%                        0.0                       0.0
# max                        0.0                       0.0
#
#        Synergistia_percentage  Synergistota_percentage  \
# count                     1.0                      1.0
# mean                      0.0                      0.0
# std                       NaN                      NaN
# min                       0.0                      0.0
# 25%                       0.0                      0.0
# 50%                       0.0                      0.0
# 75%                       0.0                      0.0
# max                       0.0                      0.0
#
#        Vampirivibrionia_percentage  Verrucomicrobiae_percentage  \
# count                          1.0                          1.0
# mean                           0.0                          0.0
# std                            NaN                          NaN
# min                            0.0                          0.0
# 25%                            0.0                          0.0
# 50%                            0.0                          0.0
# 75%                            0.0                          0.0
# max                            0.0                          0.0
#
#        Verrucomicrobiota_percentage
# count                           1.0
# mean                            0.0
# std                             NaN
# min                             0.0
# 25%                             0.0
# 50%                             0.0
# 75%                             0.0
# max                             0.0
#
# [8 rows x 31 columns]

# %% [markdown]
# # Diabetes

# %%
file_path = 'diabetes.xlsx'
analyses_path = 'C:\\Users\\admin1\\Documents\\Микробиом\\diabetes\\' #Путь до исследований
df_diabetes = get_df(file_path, analyses_path, 0)

# %%
file_path = 'health.xlsx'
analyses_path = 'C:\\Users\\admin1\\Documents\\Микробиом\\health\\' #Путь до исследований
df_health = get_df(file_path, analyses_path, 1)

# %%
df_common = df_health.append(df_diabetes).fillna(0)
# Out:
# C:\Users\admin1\AppData\Local\Temp\ipykernel_1448\4232847631.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_common = df_health.append(df_diabetes).fillna(0)

# %% [markdown]
# ## Tree classifier

# %%
feature_cols = list(df_common.columns)
feature_cols = [col for col in feature_cols if col != 'BioSample' and col != 'target' and col != 'Region']
X = df_common[feature_cols] # Features
y = df_common.target # Target variable
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="entropy", max_depth=5)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9007633587786259
#               precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86        51
#            1       0.89      0.96      0.92        80
#
#     accuracy                           0.90       131
#    macro avg       0.91      0.88      0.89       131
# weighted avg       0.90      0.90      0.90       131

# %% [markdown]
# # All classes

# %%
file_path = 'diabetes.xlsx'
analyses_path = 'C:\\Users\\admin1\\Documents\\Микробиом\\diabetes\\' #Путь до исследований
df_diabetes = get_df(file_path, analyses_path, 0)

file_path = 'health.xlsx'
analyses_path = 'C:\\Users\\admin1\\Documents\\Микробиом\\health\\' #Путь до исследований
df_health = get_df(file_path, analyses_path, 1)

file_path = 'obesity.xlsx'
analyses_path = 'C:\\Users\\admin1\\Documents\\Микробиом\\obesity\\' #Путь до исследований
df_obesity = get_df(file_path, analyses_path, 2)

df_common = df_diabetes.append(df_obesity).append(df_health).fillna(0)
# Out:
# C:\Users\admin1\AppData\Local\Temp\ipykernel_1448\3901147220.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_common = df_diabetes.append(df_obesity).append(df_health).fillna(0)
# C:\Users\admin1\AppData\Local\Temp\ipykernel_1448\3901147220.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_common = df_diabetes.append(df_obesity).append(df_health).fillna(0)

# %% [markdown]
# ## Tree classifier

# %%
feature_cols = list(df_common.columns)
feature_cols = [col for col in feature_cols if col != 'BioSample' and col != 'target' and col != 'Region']
X = df_common[feature_cols] # Features
y = df_common.target # Target variable
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="entropy", max_depth=5)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8467741935483871
#               precision    recall  f1-score   support
#
#            0       0.72      0.44      0.55        52
#            1       0.91      0.94      0.92        82
#            2       0.84      0.96      0.90       114
#
#     accuracy                           0.85       248
#    macro avg       0.82      0.78      0.79       248
# weighted avg       0.84      0.85      0.83       248

# %% [markdown]
# ## Tree classifier by Region

# %% [markdown]
# List of regions

# %%
regions = np.unique(df_common['Region'].to_numpy()).tolist()
regions
# Out:
# ['Africa',
#  'America',
#  'Asia',
#  'Australia',
#  'Europe',
#  'South America',
#  'Unknown']

# %% [markdown]
# loop over regions

# %%
def classifyByRegion(df_common):
    feature_cols = list(df_common.columns)
    feature_cols = [col for col in feature_cols if col != 'BioSample' and col != 'target' and col != 'Region']
    X = df_common[feature_cols] # Features
    y = df_common.target # Target variable
    # Split dataset into training set and test set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test
    # Create Decision Tree classifer object
    clf = DecisionTreeClassifier(criterion="entropy", max_depth=5)

    # Train Decision Tree Classifer
    clf = clf.fit(X_train,y_train)

    #Predict the response for test dataset
    y_pred = clf.predict(X_test)
    # Model Accuracy, how often is the classifier correct?
    print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))

# %%
for region in regions:
    df_region = df_common.query('Region == @region')
    if(df_region.shape[0] < 10):
        continue
    print(region)
    classifyByRegion(df_region)
# Out:
# Africa
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            2       1.00      1.00      1.00         7
#
#     accuracy                           1.00         7
#    macro avg       1.00      1.00      1.00         7
# weighted avg       1.00      1.00      1.00         7
#
# America
# Accuracy: 0.8809523809523809
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90        27
#            2       0.75      1.00      0.86        15
#
#     accuracy                           0.88        42
#    macro avg       0.88      0.91      0.88        42
# weighted avg       0.91      0.88      0.88        42
#
# Asia
# Accuracy: 0.9090909090909091
#               precision    recall  f1-score   support
#
#            0       0.93      0.65      0.76        20
#            1       0.84      0.96      0.90        27
#            2       0.95      1.00      0.98        41
#
#     accuracy                           0.91        88
#    macro avg       0.91      0.87      0.88        88
# weighted avg       0.91      0.91      0.90        88
#
# Europe
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        18
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        31
#    macro avg       1.00      1.00      1.00        31
# weighted avg       1.00      1.00      1.00        31
#
# South America
# Accuracy: 0.9390243902439024
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.97      1.00      0.99        35
#            2       0.98      0.91      0.94        46
#
#     accuracy                           0.94        82
#    macro avg       0.65      0.64      0.64        82
# weighted avg       0.96      0.94      0.95        82
